# %% [markdown]
# # Note
#
# 주어진 data에 대해서 coef를 최적화해서 구했지만,
# 통계적으로 데이터를 더 주었을 때 바뀔 확률이 P이다.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import time

def stopwatch_begin():
    return time.time()

def stopwatch_end(start_time):
    end_time = time.time()
    response_time = end_time - start_time
    print('response time=%f seconds' % (response_time))
    
def load_data():
    EXCEL_FILE = 'score.xlsx'
    data = pd.read_excel(EXCEL_FILE)

    X = data[['homework', 'attendance', 'final']]
    X = np.array(X)
    y = data['score']
    y = np.array(y)

    return X, y

def least_square(X, y):
    X_const = sm.add_constant(X)
    
    model = sm.OLS(y, X_const)
    ls = model.fit()
    
    print(ls.summary())
    
    print(ls.params)
    
    ls_c = ls.params[0]
    ls_homework = ls.params[1]
    ls_attendance = ls.params[2]
    ls_final = ls.params[3]
    
    return ls_c, ls_homework, ls_attendance, ls_final

def gradient_descent(X, y):
    start_time = stopwatch_begin()
    
    epochs = 1000000
    min_grad = 0.000001
    learning_rate_m = 0.001
    learning_rate_c = 0.1
    
    num_params = 3
    
    c = 0.0
    m = [0.0]*num_params
    
    n = len(y)
    
    for epoch in range(epochs):
        c_partial = 0.0
        m_partial = [0.0]*num_params
        
        for i in range(n):
            y_pred = c
            for j in range(num_params):
                y_pred += m[j] * X[i][j]
                
            c_partial += (y_pred-y[i])
            for j in range(num_params):
                m_partial[j] += (y_pred - y[i])*X[i][j]
                
        c_partial *= 2/n
        for j in range(num_params):
            m_partial[j] *= 2/n
        
        delta_c = -learning_rate_c * c_partial
        delta_m = [0.0] * num_params
        for j in range(num_params):
            delta_m[j] = -learning_rate_m * m_partial[j]
            
        c += delta_c
        for j in range(num_params):
            m[j] += delta_m[j]
            
        break_condition = True
        
        if abs(delta_c) > min_grad:
            break_condition = False
        for j in range(num_params):
            if abs(delta_m[j]) > min_grad:
                break_condition = False
                
        if break_condition:
            break
            
        if (epoch % 1000 == 0):
            print('epoch:', epoch, 'delta_m=', delta_m, 'delta_c=', delta_c, 'm=', m, 'c=', c)
            
    stopwatch_end(start_time)
    
    return c, m[0], m[1], m[2]

def gradient_descent_vectorized(X, y):
    start_time = stopwatch_begin()
    
    epochs = 1000000
    min_grad = 0.000001
    learning_rate_m = 0.001
    learning_rate_c = 0.1
    
    num_params = 3
    
    m = np.zeros(num_params)
    c = 0.0
    
    n = len(y)
    
    for epoch in range(epochs):

        y_pred = np.sum( m * X, axis=1 ) + c
        # axis=1이면, row(tuple) 갯수 정보를 유지한다.

        c_partial = np.sum (2*(y_pred-y)) / n
        m_partial = np.sum(2*((y_pred-y) * np.transpose(X)), axis=1 ) /n

        delta_c = -learning_rate_c * c_partial
        delta_m = -learning_rate_m * m_partial

        if abs(delta_c) < min_grad and np.all(np.abs(delta_m)) < min_grad:
            break

        c += delta_c
        m += delta_m

        if ( epoch % 1000 == 0 ):
            print("""epoch %d: delta_c=%f, delta_homework=%f, delta_attendance=%f, delta_final=%f,
                      c=%f, homework=%f, attendance=%f, final=%f\n""" %(epoch, delta_c, delta_m[0], delta_m[1], delta_m[2], c, m[0], m[1], m[2]) )
        
    stopwatch_end(start_time)
            
    return c, m[0], m[1], m[2]

if __name__=='__main__':
    X, y = load_data()
    
    ls_c, ls_homework, ls_attendance, ls_final = least_square(X, y)
    gd_c, gd_homework, gd_attendance, gd_final = gradient_descent(X, y)
    input('Enter:')
    gdv_c, gdv_homework, gdv_attendance, gdv_final = gradient_descent_vectorized(X, y)
    
    print('ls_c=%f, ls_homework=%f, ls_attendance=%f, ls_final=%f' % (ls_c, ls_homework, ls_attendance, ls_final))
    print('gd_c=%f, gd_homework=%f, gd_attendance=%f, gd_final=%f' % (gd_c, gd_homework, gd_attendance, gd_final))
    print('gdv_c=%f, gdv_homework=%f, gdv_attendance=%f, gdv_final=%f' %(gdv_c, gdv_homework, gdv_attendance, gdv_final))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     137.9
# Date:                Fri, 11 Nov 2022   Prob (F-statistic):           3.76e-33
# Time:                        09:04:42   Log-Likelihood:                -300.38
# No. Observations:                  92   AIC:                             608.8
# Df Residuals:                      88   BIC:                             618.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.6583     15.619     -0.234      0.815     -34.697      27.380
# x1             1.7178      0.280      6.135      0.000       1.161       2.274
# x2             1.9348      2.236      0.865      0.389      -2.508       6.377
# x3             1.4972      0.091     16.481      0.000       1.317       1.678
# ==============================================================================
# Omnibus:                        0.200   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.905   Jarque-Bera (JB):                0.296
# Skew:                          -0.105   Prob(JB):                        0.862
# Kurtosis:                       2.818   Cond. No.                         584.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-3.65834768  1.717757    1.93475452  1.49720516]
# epoch: 0 delta_m= [2.3850900652173914, 1.0037138195652173, 2.010578271739131] delta_c= 12.808826086956522 m= [2.3850900652173914, 1.0037138195652173, 2.010578271739131] c= 12.808826086956522
# epoch: 1000 delta_m= [2.8242752042874894e-06, 0.0001487101487951644, -1.122654858396385e-06] delta_c= -0.0011997419586772474 m= [1.7731482195415986, 0.6812926464925442, 1.505759275228941] c= 4.9956111484463825
# epoch: 2000 delta_m= [-6.23488762938622e-06, 0.00013821564356682854, -9.417799522613857e-07] delta_c= -0.0009519072403523734 m= [1.7685964130239977, 0.8268312345299683, 1.5047444979622844] c= 3.9561895496224375
# epoch: 3000 delta_m= [-5.60316627527482e-06, 0.00012207594380422602, -8.30701256153841e-07] delta_c= -0.0008389770229098403 m= [1.762652810010138, 0.9568261923656416, 1.503859645155428] c= 3.062364160603205
# epoch: 4000 delta_m= [-4.946789323187556e-06, 0.00010775147071003085, -7.332135664789074e-07] delta_c= -0.0007405105952154045 m= [1.7573846260491386, 1.071584059652212, 1.503078752322207] c= 2.2736979873828744
# epoch: 5000 delta_m= [-4.366305893139818e-06, 9.510704637746755e-05, -6.471722437339234e-07] delta_c= -0.000653612892815229 m= [1.7527344011939316, 1.1728755057943683, 1.5023894972326612] c= 1.5775834202475425
#
# epoch 3000: delta_c=-0.000839, delta_homework=-0.000006, delta_attendance=0.000122, delta_final=-0.000001,
#                       c=3.062364, homework=1.762653, attendance=0.956826, final=1.503860
#
# epoch 4000: delta_c=-0.000741, delta_homework=-0.000005, delta_attendance=0.000108, delta_final=-0.000001,
#                       c=2.273698, homework=1.757385, attendance=1.071584, final=1.503079
#
# epoch 5000: delta_c=-0.000654, delta_homework=-0.000004, delta_attendance=0.000095, delta_final=-0.000001,
#                       c=1.577583, homework=1.752734, attendance=1.172876, final=1.502389
#
# epoch 6000: delta_c=-0.000577, delta_homework=-0.000004, delta_attendance=0.000084, delta_final=-0.000001,
#                       c=0.963157, homework=1.748630, attendance=1.262281, final=1.501781
#
# epoch 7000: delta_c=-0.000509, delta_homework=-0.000003, delta_attendance=0.000074, delta_final=-0.000001,
#                       c=0.420832, homework=1.745007, attendance=1.341194, final=1.501244
#
# epoch 8000: delta_c=-0.000449, delta_homework=-0.000003, delta_attendance=0.000065, delta_final=-0.000000,
#                       c=-0.057852, homework=1.741809, attendance=1.410847, final=1.500770
#
# epoch 9000: delta_c=-0.000397, delta_homework=-0.000003, delta_attendance=0.000058, delta_final=-0.000000,
#                       c=-0.480364, homework=1.738987, attendance=1.472327, final=1.500352
#
# epoch 10000: delta_c=-0.000350, delta_homework=-0.000002, delta_attendance=0.000051, delta_final=-0.000000,
#                       c=-0.853294, homework=1.736495, attendance=1.526592, final=1.499983
#
# epoch 11000: delta_c=-0.000309, delta_homework=-0.000002, delta_attendance=0.000045, delta_final=-0.000000,
#                       c=-1.182462, homework=1.734297, attendance=1.574489, final=1.499657
#
# epoch 12000: delta_c=-0.000273, delta_homework=-0.000002, delta_attendance=0.000040, delta_final=-0.000000,
#                       c=-1.473003, homework=1.732356, attendance=1.616766, final=1.499369
#
# epoch 13000: delta_c=-0.000241, delta_homework=-0.000002, delta_attendance=0.000035, delta_final=-0.000000,
#                       c=-1.729449, homework=1.730643, attendance=1.654081, final=1.499115
#
# epoch 14000: delta_c=-0.000213, delta_homework=-0.000001, delta_attendance=0.000031, delta_final=-0.000000,
#                       c=-1.955802, homework=1.729130, attendance=1.687017, final=1.498891
#
# epoch 15000: delta_c=-0.000188, delta_homework=-0.000001, delta_attendance=0.000027, delta_final=-0.000000,
#                       c=-2.155592, homework=1.727796, attendance=1.716089, final=1.498693
#
# epoch 16000: delta_c=-0.000166, delta_homework=-0.000001, delta_attendance=0.000024, delta_final=-0.000000,
#                       c=-2.331938, homework=1.726618, attendance=1.741749, final=1.498519
#
# epoch 17000: delta_c=-0.000146, delta_homework=-0.000001, delta_attendance=0.000021, delta_final=-0.000000,
#                       c=-2.487589, homework=1.725578, attendance=1.764398, final=1.498364
# epoch 18000: delta_c=-0.000129, delta_homework=-0.000001, delta_attendance=0.000019, delta_final=-0.000000,
#                       c=-2.624976, homework=1.724660, attendance=1.784389, final=1.498228
#
# epoch 19000: delta_c=-0.000114, delta_homework=-0.000001, delta_attendance=0.000017, delta_final=-0.000000,
#                       c=-2.746240, homework=1.723850, attendance=1.802034, final=1.498108
#
# epoch 20000: delta_c=-0.000100, delta_homework=-0.000001, delta_attendance=0.000015, delta_final=-0.000000,
#                       c=-2.853274, homework=1.723135, attendance=1.817608, final=1.498002
#
# epoch 21000: delta_c=-0.000089, delta_homework=-0.000001, delta_attendance=0.000013, delta_final=-0.000000,
#                       c=-2.947748, homework=1.722504, attendance=1.831355, final=1.497909
#
# epoch 22000: delta_c=-0.000078, delta_homework=-0.000001, delta_attendance=0.000011, delta_final=-0.000000,
#                       c=-3.031136, homework=1.721947, attendance=1.843489, final=1.497826
#
# epoch 23000: delta_c=-0.000069, delta_homework=-0.000000, delta_attendance=0.000010, delta_final=-0.000000,
#                       c=-3.104738, homework=1.721455, attendance=1.854199, final=1.497753
#
# epoch 24000: delta_c=-0.000061, delta_homework=-0.000000, delta_attendance=0.000009, delta_final=-0.000000,
#                       c=-3.169703, homework=1.721021, attendance=1.863652, final=1.497689
#
# epoch 25000: delta_c=-0.000054, delta_homework=-0.000000, delta_attendance=0.000008, delta_final=-0.000000,
#                       c=-3.227044, homework=1.720638, attendance=1.871996, final=1.497632
#
# epoch 26000: delta_c=-0.000048, delta_homework=-0.000000, delta_attendance=0.000007, delta_final=-0.000000,
#                       c=-3.277657, homework=1.720300, attendance=1.879360, final=1.497582
#
# epoch 27000: delta_c=-0.000042, delta_homework=-0.000000, delta_attendance=0.000006, delta_final=-0.000000,
#                       c=-3.322330, homework=1.720002, attendance=1.885861, final=1.497538
#
# epoch 28000: delta_c=-0.000037, delta_homework=-0.000000, delta_attendance=0.000005, delta_final=-0.000000,
#                       c=-3.361761, homework=1.719738, attendance=1.891598, final=1.497499
#
# epoch 29000: delta_c=-0.000033, delta_homework=-0.000000, delta_attendance=0.000005, delta_final=-0.000000,
#                       c=-3.396565, homework=1.719506, attendance=1.896663, final=1.497464
#
# epoch 30000: delta_c=-0.000029, delta_homework=-0.000000, delta_attendance=0.000004, delta_final=-0.000000,
#                       c=-3.427285, homework=1.719301, attendance=1.901133, final=1.497434
#
# epoch 31000: delta_c=-0.000025, delta_homework=-0.000000, delta_attendance=0.000004, delta_final=-0.000000,
#                       c=-3.454400, homework=1.719119, attendance=1.905078, final=1.497407
#
# epoch 32000: delta_c=-0.000022, delta_homework=-0.000000, delta_attendance=0.000003, delta_final=-0.000000,
#                       c=-3.478333, homework=1.718960, attendance=1.908561, final=1.497383
#
# epoch 33000: delta_c=-0.000020, delta_homework=-0.000000, delta_attendance=0.000003, delta_final=-0.000000,
#                       c=-3.499457, homework=1.718818, attendance=1.911634, final=1.497362
#
# epoch 34000: delta_c=-0.000018, delta_homework=-0.000000, delta_attendance=0.000003, delta_final=-0.000000,
#                       c=-3.518103, homework=1.718694, attendance=1.914347, final=1.497344
#
# epoch 35000: delta_c=-0.000015, delta_homework=-0.000000, delta_attendance=0.000002, delta_final=-0.000000,
#                       c=-3.534560, homework=1.718584, attendance=1.916742, final=1.497328
#
# epoch 36000: delta_c=-0.000014, delta_homework=-0.000000, delta_attendance=0.000002, delta_final=-0.000000,
#                       c=-3.549086, homework=1.718487, attendance=1.918856, final=1.497313
#
# epoch 37000: delta_c=-0.000012, delta_homework=-0.000000, delta_attendance=0.000002, delta_final=-0.000000,
#                       c=-3.561908, homework=1.718401, attendance=1.920722, final=1.497301
#
# epoch 38000: delta_c=-0.000011, delta_homework=-0.000000, delta_attendance=0.000002, delta_final=-0.000000,
#                       c=-3.573225, homework=1.718326, attendance=1.922368, final=1.497289
#
# epoch 39000: delta_c=-0.000009, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.583214, homework=1.718259, attendance=1.923822, final=1.497280
#
# epoch 40000: delta_c=-0.000008, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.592031, homework=1.718200, attendance=1.925105, final=1.497271
#
# epoch 41000: delta_c=-0.000007, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.599813, homework=1.718148, attendance=1.926237, final=1.497263
#
# epoch 42000: delta_c=-0.000006, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.606682, homework=1.718102, attendance=1.927237, final=1.497256
#
# epoch 43000: delta_c=-0.000006, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.612745, homework=1.718062, attendance=1.928119, final=1.497250
#
# epoch 44000: delta_c=-0.000005, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.618096, homework=1.718026, attendance=1.928898, final=1.497245
#
# epoch 45000: delta_c=-0.000004, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.622820, homework=1.717994, attendance=1.929585, final=1.497240
#
# epoch 46000: delta_c=-0.000004, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.626989, homework=1.717966, attendance=1.930191, final=1.497236
#
# epoch 47000: delta_c=-0.000003, delta_homework=-0.000000, delta_attendance=0.000001, delta_final=-0.000000,
#                       c=-3.630669, homework=1.717942, attendance=1.930727, final=1.497233
#
# epoch 48000: delta_c=-0.000003, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.633917, homework=1.717920, attendance=1.931200, final=1.497229
#
# epoch 49000: delta_c=-0.000003, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.636784, homework=1.717901, attendance=1.931617, final=1.497227
#
# epoch 50000: delta_c=-0.000002, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.639314, homework=1.717884, attendance=1.931985, final=1.497224
#
# epoch 51000: delta_c=-0.000002, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.641548, homework=1.717869, attendance=1.932310, final=1.497222
#
# epoch 52000: delta_c=-0.000002, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.643519, homework=1.717856, attendance=1.932597, final=1.497220
#
# epoch 53000: delta_c=-0.000002, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.645259, homework=1.717844, attendance=1.932850, final=1.497218
#
# epoch 54000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.646795, homework=1.717834, attendance=1.933074, final=1.497217
#
# epoch 55000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.648151, homework=1.717825, attendance=1.933271, final=1.497215
#
# epoch 56000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.649347, homework=1.717817, attendance=1.933445, final=1.497214
#
# epoch 57000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.650404, homework=1.717810, attendance=1.933599, final=1.497213
#
# epoch 58000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.651336, homework=1.717804, attendance=1.933734, final=1.497212
#
# epoch 59000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.652159, homework=1.717798, attendance=1.933854, final=1.497211
#
# epoch 60000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.652885, homework=1.717793, attendance=1.933960, final=1.497211
#
# epoch 61000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.653526, homework=1.717789, attendance=1.934053, final=1.497210
#
# epoch 62000: delta_c=-0.000001, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.654092, homework=1.717785, attendance=1.934135, final=1.497209
#
# epoch 63000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.654591, homework=1.717782, attendance=1.934208, final=1.497209
#
# epoch 64000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.655032, homework=1.717779, attendance=1.934272, final=1.497208
#
# epoch 65000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.655421, homework=1.717777, attendance=1.934329, final=1.497208
# epoch 66000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.655765, homework=1.717774, attendance=1.934379, final=1.497208
#
# epoch 67000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.656068, homework=1.717772, attendance=1.934423, final=1.497207
#
# epoch 68000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.656335, homework=1.717770, attendance=1.934462, final=1.497207
#
# epoch 69000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.656571, homework=1.717769, attendance=1.934496, final=1.497207
#
# epoch 70000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.656780, homework=1.717767, attendance=1.934526, final=1.497207
#
# epoch 71000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.656964, homework=1.717766, attendance=1.934553, final=1.497207
#
# epoch 72000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657126, homework=1.717765, attendance=1.934577, final=1.497206
#
# epoch 73000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657270, homework=1.717764, attendance=1.934598, final=1.497206
#
# epoch 74000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657396, homework=1.717763, attendance=1.934616, final=1.497206
#
# epoch 75000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657508, homework=1.717763, attendance=1.934632, final=1.497206
#
# epoch 76000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657606, homework=1.717762, attendance=1.934647, final=1.497206
#
# epoch 77000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657693, homework=1.717761, attendance=1.934659, final=1.497206
#
# epoch 78000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657770, homework=1.717761, attendance=1.934670, final=1.497206
#
# epoch 79000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657838, homework=1.717760, attendance=1.934680, final=1.497206
#
# epoch 80000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657898, homework=1.717760, attendance=1.934689, final=1.497206
#
# epoch 81000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657950, homework=1.717760, attendance=1.934697, final=1.497206
#
# epoch 82000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.657997, homework=1.717759, attendance=1.934704, final=1.497206
#
# epoch 83000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658038, homework=1.717759, attendance=1.934709, final=1.497205
#
# epoch 84000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658075, homework=1.717759, attendance=1.934715, final=1.497205
#
# epoch 85000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658107, homework=1.717759, attendance=1.934719, final=1.497205
#
# epoch 86000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658135, homework=1.717758, attendance=1.934724, final=1.497205
#
# epoch 87000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658160, homework=1.717758, attendance=1.934727, final=1.497205
#
# epoch 88000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658182, homework=1.717758, attendance=1.934730, final=1.497205
#
# epoch 89000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658201, homework=1.717758, attendance=1.934733, final=1.497205
#
# epoch 90000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658219, homework=1.717758, attendance=1.934736, final=1.497205
#
# epoch 91000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658234, homework=1.717758, attendance=1.934738, final=1.497205
#
# epoch 92000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658247, homework=1.717758, attendance=1.934740, final=1.497205
#
# epoch 93000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658259, homework=1.717758, attendance=1.934742, final=1.497205
#
# epoch 94000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658269, homework=1.717758, attendance=1.934743, final=1.497205
#
# epoch 95000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658278, homework=1.717757, attendance=1.934744, final=1.497205
#
# epoch 96000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658287, homework=1.717757, attendance=1.934746, final=1.497205
#
# epoch 97000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658294, homework=1.717757, attendance=1.934747, final=1.497205
#
# epoch 98000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658300, homework=1.717757, attendance=1.934748, final=1.497205
#
# epoch 99000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658306, homework=1.717757, attendance=1.934748, final=1.497205
#
# epoch 100000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658311, homework=1.717757, attendance=1.934749, final=1.497205
#
# epoch 101000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658315, homework=1.717757, attendance=1.934750, final=1.497205
#
# epoch 102000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658319, homework=1.717757, attendance=1.934750, final=1.497205
#
# epoch 103000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658322, homework=1.717757, attendance=1.934751, final=1.497205
#
# epoch 104000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658325, homework=1.717757, attendance=1.934751, final=1.497205
#
# epoch 105000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658328, homework=1.717757, attendance=1.934752, final=1.497205
#
# epoch 106000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658330, homework=1.717757, attendance=1.934752, final=1.497205
#
# epoch 107000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658332, homework=1.717757, attendance=1.934752, final=1.497205
#
# epoch 108000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658334, homework=1.717757, attendance=1.934753, final=1.497205
#
# epoch 109000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658336, homework=1.717757, attendance=1.934753, final=1.497205
#
# epoch 110000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658337, homework=1.717757, attendance=1.934753, final=1.497205
#
# epoch 111000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658338, homework=1.717757, attendance=1.934753, final=1.497205
#
# epoch 112000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658339, homework=1.717757, attendance=1.934753, final=1.497205
# epoch 113000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658340, homework=1.717757, attendance=1.934753, final=1.497205
#
# epoch 114000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658341, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 115000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658342, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 116000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658343, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 117000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658343, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 118000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658344, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 119000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658344, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 120000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658345, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 121000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658345, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 122000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658345, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 123000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658346, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 124000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658346, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 125000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658346, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 126000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658346, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 127000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658346, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 128000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 129000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 130000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 131000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 132000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 133000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 134000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 135000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 136000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 137000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 138000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 139000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 140000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 141000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 142000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658347, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 143000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 144000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 145000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 146000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934754, final=1.497205
#
# epoch 147000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 148000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 149000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 150000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 151000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 152000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 153000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 154000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 155000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 156000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 157000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 158000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 159000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
# epoch 160000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 161000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 162000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 163000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 164000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 165000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 166000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 167000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 168000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 169000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 170000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 171000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 172000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 173000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 174000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 175000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 176000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 177000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 178000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 179000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 180000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 181000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 182000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 183000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 184000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 185000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 186000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 187000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 188000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 189000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 190000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 191000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 192000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 193000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 194000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 195000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 196000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 197000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 198000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 199000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 200000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 201000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# epoch 202000: delta_c=-0.000000, delta_homework=-0.000000, delta_attendance=0.000000, delta_final=-0.000000,
#                       c=-3.658348, homework=1.717757, attendance=1.934755, final=1.497205
#
# response time=6.091748 seconds
# ls_c=-3.658348, ls_homework=1.717757, ls_attendance=1.934755, ls_final=1.497205
# gd_c=-3.650338, gd_homework=1.717811, gd_attendance=1.933589, gd_final=1.497213
# gdv_c=-3.658348, gdv_homework=1.717757, gdv_attendance=1.934755, gdv_final=1.497205
